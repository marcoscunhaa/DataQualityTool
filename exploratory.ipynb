# %%
#Importação da biblioteca
import pandas as pd
import numpy as np

# %%
#Carrega a planilha
df = pd.read_csv('Walmart Inventory.csv')

# %%
#Amostra dos 4 primeiros itens da tabela
df.head()
# Out:
#    Product_ID Product_Name  Category    Price  Stock_Quantity Last_Updated  \
# 0        6458      T-shirt  Clothing  1386.42             276   31-01-2024
# 1        4898      Blender     Appl.  1613.58             113    10/1/2021
# 2        1370   Smartphone    Mobile  1797.89             372   24/07/2022
# 3        9648    Microwave     Appl.  1007.11             355    3/17/2024
# 4        1790      T-shirt   Apparel  1979.42             402    11/1/2024
#
#   Supplier_Name  Supplier_Contact Warehouse_Location         Country  \
# 0         Bosch        -2679856.0                 E5          canada
# 1     Panasonic        -9815930.0                 B2  United Kingdom
# 2        Lenovo        -5511254.0                 E5             USA
# 3          Asus        -7210874.0                 E5  UNITED KINGDOM
# 4     Whirlpool        -2630885.0                 A1         Germany
#
#               State
# 0  British Columbia
# 1          Scotland
# 2          Illinois
# ...

# %%
#Amostra de dados aleatórios
df.sample(10)
# Out:
#       Product_ID Product_Name            Category       Price  Stock_Quantity  \
# 7503        2538       Laptop         Electronics    $577.39              292
# 8062        3480         Sofa           Furniture      251.61             255
# 6145        3340      T-shirt            Clothing  $1,604.15               90
# 1736        2649           TV  Electronic Devices      698.04             337
# 7622        7004      T-shirt              Cloth.     1133.75             499
# 7389        3599   Smartphone              Mobile    $938.50               41
# 3658        6357    Microwave                Home      192.94             152
# 3620        1304   Smartphone               Elec.       74.33              28
# 5766        9957         Sofa                Home    $116.30               22
# 6591        3190      Blender               Appl.  $1,212.52              464
#
#      Last_Updated Supplier_Name  Supplier_Contact Warehouse_Location  \
# ...

# %%
#Sumário de dados
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product_ID          10200 non-null  int64
#  1   Product_Name        10200 non-null  str
#  2   Category            10200 non-null  str
#  3   Price               10200 non-null  str
#  4   Stock_Quantity      10200 non-null  int64
#  5   Last_Updated        10200 non-null  str
#  6   Supplier_Name       10200 non-null  str
#  7   Supplier_Contact    8685 non-null   float64
#  8   Warehouse_Location  10200 non-null  str
#  9   Country             10200 non-null  str
#  10  State               10200 non-null  str
# dtypes: float64(1), int64(2), str(8)
# memory usage: 876.7 KB

# %%
#Estatística Descritiva
df.describe()
# Out:
#          Product_ID  Stock_Quantity  Supplier_Contact
# count  10200.000000    10200.000000      8.685000e+03
# mean    5461.691471      250.905882     -5.470336e+06
# std     2584.316112      143.736291      2.614542e+06
# min     1000.000000        0.000000     -9.999707e+06
# 25%     3219.750000      126.000000     -7.734583e+06
# 50%     5437.000000      254.000000     -5.489319e+06
# 75%     7659.250000      376.000000     -3.158772e+06
# max     9997.000000      500.000000     -1.001551e+06

# %%
#Lista de linhas duplicadas
df.duplicated().sum()
# Out:
# np.int64(200)

# %%
#Inconsistência de texto nas colunas
print("\nProduct:", df["Product"].unique())
print("\nCity:", df["City"].unique())
print("\nState:", df["State"].unique())
print("\nCountry:", df["Country"].unique())
# Out:
# Product: <StringArray>
# ['Headphones',          nan,      'Table',    'T-shirt',       'Sofa',
#       'Drone',         'TV',  'Chocolate',     'Laptop']
# Length: 9, dtype: str
#
# City: <StringArray>
# [    'Houston',    'New York',      'Sydney',           nan,   'São Paulo',
#  'Los Angeles',     'Seattle',       'Paris',      'Munich',    'Montreal',
#        'Miami',     'Toronto']
# Length: 12, dtype: str
#
# State: <StringArray>
# [        'Ontario',  'Rio de Janeiro',         'Bavaria',               nan,
#           'Quebec',           'Texas', 'New South Wales',      'Washington',
#    'Île-de-France',         'Florida',      'California',       'São Paulo',
#         'New York']
# Length: 13, dtype: str
#
# Country: <StringArray>
# [   'Canada',    'Brazil',   'Germany',    'CaNada',       'USA',    'canada',
#  'Australia',         nan,    'France',       'usa']
# Length: 10, dtype: str
